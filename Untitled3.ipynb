# %% [markdown]
# <a href="https://colab.research.google.com/github/mdhv11/Hugging_Face/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Hugging_face_api="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"

# %%
from transformers import pipeline

def image_to_text(url):
    image_to_text = pipeline("image-to-text",model="salesforce/blip-image-captioning-base")
    text = image_to_text(url)[0]["generated_text"]
    print (text)
    return text
image_to_text("zoro.jpg")
# Out:
# a drawing of a man with green hair holding a sword
# 'a drawing of a man with green hair holding a sword'
